# %%
import os
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
github_token = user_secrets.get_secret("GITHUB_TOKEN")

username = "Infamouszz"
repo = "RouterLM"

# !git clone https://{username}:{github_token}@github.com/{username}/{repo}.git
# Out:
# Cloning into 'RouterLM'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 77 (delta 33), reused 70 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (77/77), 61.14 KiB | 1.33 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# %cd /kaggle/working/RouterLM
# Out:
# /kaggle/working/RouterLM

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !cp -r /kaggle/input/datasets/infamouszz/datasetai/DatasetAi /kaggle/working/

# %%
# !PYTHONPATH=/kaggle/working/RouterLM python -m Src.Main
# Out:
# Running in 2 GPUs!
# Loaded 70 parts
# Dataset loaded into run successfully!
# Starting training...
# Starting Epoch [ 0 ]
# Epoch 0 | Step [0/14244] | Loss: 9.394598960876465
# Epoch 0 | Step [100/14244] | Loss: 7.349610805511475
# Epoch 0 | Step [200/14244] | Loss: 7.157476902008057
# Epoch 0 | Step [300/14244] | Loss: 7.043591499328613
# Epoch 0 | Step [400/14244] | Loss: 7.186429500579834
# Epoch 0 | Step [500/14244] | Loss: 7.103940010070801
# Epoch 0 | Step [600/14244] | Loss: 7.093456745147705
# Epoch 0 | Step [700/14244] | Loss: 7.004698753356934
# Epoch 0 | Step [800/14244] | Loss: 7.063307285308838
# Epoch 0 | Step [900/14244] | Loss: 7.040174961090088
# Epoch 0 | Step [1000/14244] | Loss: 7.1272478103637695
# Epoch 0 | Step [1100/14244] | Loss: 6.954314231872559
# Epoch 0 | Step [1200/14244] | Loss: 6.92990779876709
# Epoch 0 | Step [1300/14244] | Loss: 7.039760112762451
# Epoch 0 | Step [1400/14244] | Loss: 6.993736743927002
# ...
