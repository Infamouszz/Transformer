# %%
# %rm -rf Transformer

# %%
# !git clone https://github.com/Infamouszz/Transformer
# Out:
# Cloning into 'Transformer'...
# remote: Enumerating objects: 556, done.
# remote: Counting objects: 100% (199/199), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 556 (delta 104), reused 133 (delta 60), pack-reused 357 (from 1)
# Receiving objects: 100% (556/556), 1.41 MiB | 5.51 MiB/s, done.
# Resolving deltas: 100% (269/269), done.

# %%
# %cd /kaggle/working/Transformer
# Out:
# /kaggle/working/Transformer

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !cp -r /kaggle/input/datasets/infamouszz/datasetai-sft/DatasetAiSFT /kaggle/working/

# %%
# !cp -r /kaggle/input/datasets/infamouszz/modelai/ModelAi/parameters.pt /kaggle/working/
# Out:
# cp: cannot stat '/kaggle/input/datasets/infamouszz/modelai/ModelAi/parameters.pt': No such file or directory

# %%
# !PYTHONPATH=/kaggle/working/Transformer python -m Src.Transformer.TrainTransformer
# Out:
# Using GPU
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/kaggle/working/Transformer/Src/Transformer/TrainTransformer.py", line 15, in <module>
#     transformer.load_params(r"/kaggle/working/parameters_fixed_final.pt")
#   File "/kaggle/working/Transformer/Src/Transformer/Transformer.py", line 165, in load_params
#     state_dict = torch.load(path, map_location=DEVICE, weights_only=True)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1500, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 768, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 749, in __init__
#     super().__init__(open(name, mode))  # noqa: SIM115
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/parameters_fixed_final.pt'
